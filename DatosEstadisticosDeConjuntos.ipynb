# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoIvanNajeraDiaz/daa_2021_1/blob/master/DatosEstadisticosDeConjuntos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Author: Marco Ivan Najera Diaz

import csv
import math
import numpy 

print("Favor de digitar a partir del numero 1")
print("1. Acidez Fija 2. Acidez Volatil 3. Ácido Citrico 4. Azucar Residual 5. Clorhídricos"
" 6. Dioxido de sulfuro libre 7. Dioxido de sulfuro total 8. Densidad 9. PH 10. Sulfatos"
" 11. Alcohol 12. Calidad")

def lista(columnaA,columnaB):
    datosA = []
    with open('A.csv') as documentoA:
        lineasA = documentoA.read().splitlines()
        lineasA.pop(0)

        for i in lineasA:
            lineaA=i.split(',')
            datosA.append([float(lineaA[columnaA])])

    datosB = []
    with open('B.csv') as documentoB:
        lineasB = documentoB.read().splitlines()
        lineasB.pop(0)
        for i in lineasB:
            lineaB=i.split(',')
            datosB.append([float(lineaB[columnaB])])
    
    listaA=[] 
    for i in datosA:
        listaA.append(i[0])
    totalA=len(listaA)

    listaB=[]
    for i in datosB:
        listaB.append(i[0])
    totalB=len(listaB)

    #Media
    sumA=0
    sumB=0
    for i in listaA:
        sumA=sumA+i
        mediaA = sumA /totalA
    #Varianza
    varianzaA=numpy.var(listaA)
    #Desviacion Estandar
    desviacionA=math.sqrt(varianzaA)
    print("")
    print(f"La media de la columna seleccionada en el documento A es: {mediaA}")
    print(f"La varianza de la columna seleccionada en el documento A es: {varianzaA}")
    print(f"La desviación estándar de la columna seleccionada en el documento A es: {desviacionA} ")
    for i in listaB:
        sumB=sumB+i
        mediaB = sumB/totalB
    varianzaB=numpy.var(listaB)
    desviacionB=math.sqrt(varianzaB)
    print("")
    print(f"La media de la columna seleccionada en el documento B es: {mediaB}")
    print(f"La varianza de la columna seleccionada en el documento B es: {varianzaB}")
    print(f"La desviación estándar de la columna seleccionada en el documento B es: {desviacionB} ")

entradaA=int(input("Selecciona el número que quieres de columna en el documento A: "))
entradaB=int(input("Selecciona el número que quieres de columna en el documento B: "))
lista(entradaA-1,entradaB-1)
# Out:
# Favor de digitar a partir del numero 1
# 1. Acidez Fija 2. Acidez Volatil 3. Ácido Citrico 4. Azucar Residual 5. Clorhídricos 6. Dioxido de sulfuro libre 7. Dioxido de sulfuro total 8. Densidad 9. PH 10. Sulfatos 11. Alcohol 12. Calidad
# Selecciona el número que quieres de columna en el documento A: 1
# Selecciona el número que quieres de columna en el documento B: 1
#
# La media de la columna seleccionada en el documento A es: 8.319637273295838
# La varianza de la columna seleccionada en el documento A es: 3.0295205688671114
# La desviación estándar de la columna seleccionada en el documento A es: 1.7405518001102729
#
# La media de la columna seleccionada en el documento B es: 6.854787668436075
# La varianza de la columna seleccionada en el documento B es: 0.7119681970549558
# La desviación estándar de la columna seleccionada en el documento B es: 0.8437820791264506
