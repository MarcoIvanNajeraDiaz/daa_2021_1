# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoIvanNajeraDiaz/daa_2021_1/blob/master/2Octubre_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

with open('2017Precip.csv', newline='', encoding='latin-1') as File:
  reader = csv.reader(File)
  for row in reader:
    print(row)

with open('2018Precip.csv', newline='', encoding='latin-1') as FileDos:
  reader = csv.reader(FileDos)
  for row in reader:
    print(row)

ano= input("Digite el año: ")
estado= input("Digite el estado: ")
mes= input("Digite el mes: ")
# Out:
# ['2017', 'PRECIPITACIîN A NIVEL NACIONAL Y POR ENTIDAD FEDERATIVA', '', '', '', '', '', '', '', '', '', '', '', '']
# ['ENTIDAD', 'ENE', 'FEB', 'MAR', 'ABR', 'MAY', 'JUN', 'JUL', 'AGO', 'SEP', 'OCT', 'NOV', 'DIC', 'ANUAL']
# ['AGUASCALIENTES', '0.4 ', '2.1 ', '6.7 ', '0.4 ', '4.2 ', '43.5 ', '169.3 ', '143.8 ', '159.5 ', '21.8 ', '0.1 ', '27.6 ', '579.4 ']
# ['BAJA CALIFORNIA', '53.6 ', '44.9 ', '1.4 ', '0.0 ', '7.9 ', '0.2 ', '2.9 ', '7.1 ', '9.6 ', '0.0 ', '1.4 ', '2.8 ', '131.7 ']
# ['BAJA CALIFORNIA SUR', '8.4 ', '18.4 ', '0.5 ', '0.1 ', '1.6 ', '1.9 ', '12.1 ', '68.3 ', '59.0 ', '0.6 ', '0.2 ', '3.7 ', '174.7 ']
# ['CAMPECHE', '16.1 ', '6.9 ', '9.1 ', '65.1 ', '49.7 ', '363.6 ', '169.2 ', '202.8 ', '229.8 ', '221.7 ', '33.4 ', '40.1 ', '1,407.3 ']
# ['COAHUILA', '2.6 ', '11.1 ', '15.1 ', '23.0 ', '40.6 ', '22.6 ', '37.8 ', '45.1 ', '108.3 ', '15.2 ', '1.9 ', '35.6 ', '358.5 ']
# ...
